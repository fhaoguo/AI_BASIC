# %%
plt.scatter(*zip(*label_a))
plt.scatter(*zip(*label_b))
plt.show()

# %%
k_and_b = []
label_a_x = label_a[:, 0]
label_b_x = label_b[:, 0]

# %%
def f(k, x, b):
    return k * x + b

# %%
for i in range(100):
    k, b = (np.random.random(size=(1, 2))* 10 -5)[0]
    #print(k, b)
    if np.max(f(label_a_x, k, b)) <= -1 and np.min(f(label_b_x, k, b)) >= 1:
        print(k, b)
        k_and_b.append((k, b))
# Out:
# -1.4139913311690009 -1.2868955095378212
# -4.234564759506022 0.20333764811070765
# -3.6490774934982473 -0.6867366077362416
# -4.722953052932254 1.9896035665688352
# -2.06651453157468 -2.301149892281915
# -1.8618719045282495 -2.4084700495676703
# -3.7889275676702807 -2.8992452716250106
# -3.8085656083540274 -2.1955440598000275
# -3.740440470856231 -4.325279884581081
# -2.252810470160055 -0.8587801540399065
# -4.826128708668861 3.749034464021351
# -1.3164894245477465 -1.5348804932340796
# -4.543138290481217 -2.0781504018730557
# -4.507720986437075 -3.8832897464801563
# -1.3978547927094596 -0.22254012401132695
# -1.8748365758270213 -0.18847536377041685
# -3.23065896859954 -4.836319884925402
# -4.997123891339371 0.8566836450399942
# -3.3465740109788946 -2.390876900421243
# -3.478732055180127 -2.0099994901940574
# -2.5446850231717386 -4.85707194691149
# -3.163668322918064 2.0448862634747407
# -4.8872409474440275 3.3251455543424253
# -2.6021791746789824 -4.837333817158048

# %%
x = np.concatenate((label_a_x, label_b_x))
x
# Out:
# array([  2.562965  ,   6.35409888,   7.59972693,   6.06894653,
#          4.9977858 ,   5.44011315,   7.25892396,   3.79222559,
#          5.96302644,   6.70156148,   6.68147117,   9.45454838,
#          4.0372288 ,   7.97382795,   6.51359416,   8.54740036,
#          6.96152969,   0.99078805,   8.76402601,   6.84571347,
#          5.27665825,   9.34204207,   3.45438734,   9.0729012 ,
#          5.7818953 ,   8.58516394,   7.25078632,   5.55796709,
#          5.21185431,   5.75289783,  10.3830112 ,   4.48179415,
#          4.9467443 ,   9.33445549,   5.12747153,   5.45233546,
#          3.05823048,   4.86777362,   9.55473793,   4.30942694,
#          4.5253063 ,   8.22203744,   9.0016335 ,   4.83815663,
#          4.25005265,   7.10353201,   2.71403808,   7.15522275,
#          5.91757183,   7.83703747,  -7.26408207,  -5.36245695,
#         -5.31491981,  -7.10574332,  -4.93108354,  -4.0859528 ,
#         -4.29348597,  -4.9554073 ,  -3.1194388 ,  -6.75388934,
#         -6.37716602,  -6.81820569,  -4.66254341,  -3.7158097 ,
#         -7.15579986,  -6.7099744 ,  -4.78382496,  -6.13389872,
#         -6.6485063 , -11.69205155,  -3.13838239,  -5.82227393,
#         -5.0252505 ,  -3.93112377,  -4.87613056,  -6.93156702,
#         -7.58557977,  -9.20614424, -10.64168015,  -2.39840435,
#         -4.8793944 ,  -9.55860059,  -8.56869434,  -6.3008088 ,
#         -8.1008482 ,  -4.88778929,  -7.10797917,  -4.7035907 ,
#         -4.2314553 ,  -5.84179441,  -5.39541714,  -4.39817286,
#         -6.38916261,  -7.68964544,  -5.56613114,  -4.4103383 ,
#         -8.01724369, -11.35224239,  -7.24989519,  -4.84551781])

# %%
for k, b in k_and_b:
    plt.plot(x, f(x, k, b))

# %%
k_star, b_star = sorted(k_and_b, key=lambda t: abs(t[0]))[0]
plt.plot(x, f(x, k_star, b_star), '-o')
plt.show()
